# %%
import matplotlib.pyplot as plt
import numpy as np
import random as rnd
import math as m
import pandas as pd
import scipy.stats as stat
import seaborn as sb
from scipy.integrate import quad
from scipy.integrate import dblquad
from scipy.special import comb



expon = lambda n: stat.gamma(n, loc = 1)
my_norm = lambda exp, disp: stat.norm(loc = exp, scale = m.sqrt(disp))

# %%
theta = 2
samplesize = 1000

def new_pdf(my_theta, x):
    return 0.5 * (my_norm(my_theta, m.exp(my_theta**(-2))).pdf(x) + stat.norm().pdf(x))

def get_sample(samplesize):
    answer = []
    xi = stat.binom(samplesize, 0.5).rvs(1)
    sample1 = my_norm(theta, m.exp(1 / (theta * theta))).rvs(xi)
    sample2 = stat.norm(0, 1).rvs(samplesize - xi)
    
    return list(sample1) + list(sample2);

def likelihood(distr, sample):
    L = 0
    for i in range(len(sample)):
        L += np.log(distr(sample[i]))
    return L;

def likelihood1(my_theta):
    L = 0
    for elem in mini_sample:
        L += np.log(new_pdf(my_theta, elem))
    return L;

# %%
x_axis = np.linspace(1, 3, 100)
mini_sample = get_sample(samplesize)
y_axis = [likelihood1(elem) for elem in x_axis]
plt.plot(x_axis, y_axis)
plt.title('likelihood')
plt.xlabel('$\\theta$')
plt.show()

# %%
def get_sample2(samplesize):
    answer = []
    xi = stat.binom(samplesize, 0.5).rvs(1)
    sample1 = my_norm(theta, m.exp(1 / (theta * theta * theta * theta))).rvs(xi)
    sample2 = stat.beta(2, 5).rvs(samplesize - xi)
    
    return list(sample1) + list(sample2);

def new_pdf2(my_theta, x):
    return 0.5 * (my_norm(my_theta, m.exp(my_theta**(-4))).pdf(x) + stat.norm().pdf(x))

def likelihood2(my_theta):
    L = 0
    for elem in mini_sample:
        L += np.log(new_pdf2(my_theta, elem))
    return L;

# %%
samplesize = 1000
mini_sample = get_sample2(samplesize)
y_axis = [likelihood2(elem) for elem in x_axis]
plt.plot(x_axis, y_axis)
plt.title('likelihood for normal + beta')
plt.xlabel('$\\theta$')
plt.show()
