# %%
import matplotlib.pyplot as plt
import numpy as np
import random as rnd
import math as m
import pandas as pd
import scipy.stats as stat
import seaborn as sb
from scipy.integrate import quad
from scipy.integrate import dblquad
from scipy.special import comb



expon = lambda n: stat.gamma(n, loc = 1)
my_norm = lambda exp, disp: stat.norm(loc = exp, scale = m.sqrt(disp))

# %%
def real(x):
    return (stat.binom(n, 0.3).pmf(x))
def asymp(x):
    return m.exp(-(x - 0.3 * n)**2 / (2 * 0.3 * 0.7 * n))

for n in [100, 1000, 10000]
    for x in [0.3 * n, 0.15 * n]:
        print('n = ', n, 'x = ', x, '$P_real = $', )
# Out:
# 0.04900995010000009
# 0.04896983531023591
# 0.04894123581227394
# 0.04891981559586811
# 0.04890317281799017
# 0.048889869534228136
# 0.0488789922522731
# 0.04886993281129881
# 0.04886227064981796
# 0.048855705648663816
# 0.04885001789563237
# 0.048845042569365726
# 0.04884065370486401
# 0.04883675338038196
# 0.04883326432487012
# 0.04883012474683324
# 0.048827284642970814
# 0.04882470311503839
# 0.048822346387668136
# 0.04882018632241558
# 0.048818199288886865
# 0.04881636529671696
# 0.04881466732067341
# 0.0488130907705423
# 0.048811623070831534
# 0.048810253324615305
# 0.048808972042497345
# 0.048807770922485005
# 0.04880664266987367
# 0.048805580848999
# 0.04880457976037933
# 0.04880363433838786
# 0.048802740065520434
# 0.048801892900206534
# 0.04880108921574933
# 0.04880032574840909
# 0.04879959955312374
# 0.048798907965524885
# 0.048798248569286495
# 0.048797619167904815
# 0.048797017760272676
# 0.04879644251941462
# 0.048795891773937505
# 0.04879536399184259
# 0.048794857766264244
# 0.04879437180296864
# 0.04879390490929081
# 0.04879345598436746
# 0.04879302401047392
# 0.04879260804530483
# 0.048792207215148875
# 0.048791820708726674
# 0.04879144777171951
# 0.04879108770186524
# 0.04879073984454596
# 0.0487904035887915
# 0.04879007836373128
# 0.048789763635345595
# 0.0487894589035226
# 0.04878916369943942
# 0.048788877583136325
# 0.048788600141323024
# 0.04878833098540425
# 0.04878806974964034
# 0.04878781608951921
# 0.04878756968022091
# 0.04878733021523263
# 0.04878709740507026
# 0.048786870976130214
# 0.04878665066959764
# 0.04878643624046719
# 0.048786227456634856
# 0.04878602409807242
# 0.048785825956013884
# 0.04878563283229065
# 0.04878544453863398
# 0.0487852608960877
# 0.04878508173440743
# 0.04878490689157888
# 0.04878473621330226
# 0.04878456955253041
# 0.048784406769058375
# 0.04878424772914991
# 0.0487840923051317
# 0.04878394037506173
# 0.04878379182244963
# 0.04878364653590539
# 0.04878350440888346
# 0.04878336533943328
# 0.04878322922994427
# 0.04878309598690078
# 0.04878296552069461
# 0.04878283774542813
# 0.04878271257868394
# 0.04878258994140072

# %%
theta = 0.1
samplesize = 50

def new_pdf(x):
    return 0.5 * (my_norm(theta, m.exp(theta**(-2))).pdf(x) + stat.norm().pdf(x))

def new_cdf(x):
    return 0.5 * (my_norm(theta, m.exp(theta**(-2))).cdf(x) + stat.norm().cdf(x))

def new_ppf(x):
    return 0.5 * (my_norm(theta, m.exp(theta**(-2))).ppf(x) + stat.norm().ppf(x))

sample_r = stat.uniform.rvs(size = samplesize)
sample = new_ppf(sample_r)
print(stat.norm.ppf(0.5))
# Out:
# 0.0
