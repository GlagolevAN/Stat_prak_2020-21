# %%
import matplotlib.pyplot as plt
import numpy as np
import random as rnd
import math as m
import pandas as pd
import scipy.stats as stat
import scipy.optimize as opt
import seaborn as sb
from scipy.integrate import quad
from scipy.integrate import dblquad
from scipy.special import comb

#plt.style.use('ggplot')

my_norm = lambda exp, disp: stat.norm(loc = exp, scale = m.sqrt(disp))

# %%
theta0 = 0
x_axis = np.linspace(-1.1, 1.1, 1000)

x_axis_2 = np.linspace(0.9, 2.1, 1000)

for theta1 in [-1, 1]:
    for n in [10]:
        
        plt.plot(x_axis, (1 - stat.uniform(theta0, 1).cdf(x_axis))**n, label = '1 Род')
        plt.plot(x_axis, 1 - (1 - stat.uniform(theta1, 1).cdf(x_axis))**n, label = '2 Род')
        plt.legend()
        plt.title('$X_{(1)} > C \\qquad \\theta_1 = $' + str(theta1))
        plt.show()
        
        plt.plot(x_axis, 1 - (1 - stat.uniform(theta0, 1).cdf(x_axis))**n, label = '1 Род')
        plt.plot(x_axis, (1 - stat.uniform(theta1, 1).cdf(x_axis))**n, label = '2 Род')
        plt.legend()
        plt.title('$X_{(1)} < C \\qquad \\theta_1 = $' + str(theta1))
        plt.show()
        
        plt.plot(x_axis_2, 1 - (stat.uniform(theta0, 1).cdf(x_axis_2))**n, label = '1 Род')
        plt.plot(x_axis_2, (stat.uniform(theta1, 1).cdf(x_axis_2))**n, label = '2 Род')
        plt.legend()
        plt.title('$X_{(n)} > C \\qquad \\theta_1 = $' + str(theta1))
        plt.show()
