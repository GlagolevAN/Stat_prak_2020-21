# %%
import matplotlib.pyplot as plt
import numpy as np
import random as rnd
import math as m
import pandas as pd
import scipy.stats as stat
import scipy.optimize as opt
import seaborn as sb
from scipy.integrate import quad
from scipy.integrate import dblquad
from scipy.special import comb
from sklearn.linear_model import LinearRegression
plt.style.use('ggplot')

my_norm = lambda exp, disp: stat.norm(loc = exp, scale = m.sqrt(disp))

# %%
def pmone():
    return 2 * stat.bernoulli(0.5).rvs() - 1

# %%
X = stat.norm
X

# %%
def comparison(Y, iters = 100, samplesize = 50):
    pmw = []; pks = [];
    for i in range(iters):
        xsample = X(0,1).rvs(samplesize)
        ysample = Y.rvs(samplesize)
        pmw.append(stat.mannwhitneyu(xsample, ysample, use_continuity=False, alternative='two-sided')[1])
        pks.append(stat.ks_2samp(xsample, ysample, alternative='two-sided', mode='auto')[1])
    
    xaxes = np.linspace(0, 1, iters)
    plt.plot(np.sort(pmw), xaxes, label = 'Манна - Уитни')
    plt.plot(sorted(pks), xaxes, label = 'Колмогорова - Смирнова')
    plt.plot(xaxes, xaxes)
    plt.legend()
    plt.show()

# %%
def double_pvalue(Y, perms = 10000, samplesize = 50):
    xsample = X(0,1).rvs(samplesize)
    ysample = Y.rvs(samplesize)
    
    pmw = stat.mannwhitneyu(xsample, ysample, use_continuity=False, alternative='two-sided')[1]
    pks = stat.ks_2samp(xsample, ysample, alternative='two-sided', mode='exact')[1]
    
    countermw = 0; counterks = 0;
    for i in range(perms):
        tmp = np.concatenate((xsample, ysample), axis = None)
        
        tmp = np.random.permutation(tmp)
        #ysample = np.random.permutation(ysample)
        xsample = tmp[:samplesize]
        ysample = tmp[samplesize:2 * samplesize]
        
        if (stat.mannwhitneyu(xsample, ysample, use_continuity=False, alternative='two-sided')[1] > pmw):
            countermw += 1
        
        if (stat.ks_2samp(xsample, ysample, alternative='two-sided', mode='exact')[1] > pks):
            counterks += 1
            
    print('Манна - Уитни:')
    print('Встроенный:', pmw, 'Перестановочный:', 1 - (countermw + 1) / (perms + 1))
    
    print('Колмогорова - Смирнова:')
    print('Встроенный:', pks, 'Перестановочный:', 1 - (counterks + 1) / (perms + 1))

# %% [markdown]
# ## $\mathcal{N}(0,1)$

# %%
comparison(stat.norm(0,1), samplesize = 500)

# %%
double_pvalue(stat.norm(0,1), perms = 100000)
# Out:
# Манна - Уитни:
# Встроенный: 0.6892732232396359 Перестановочный: 0.6891731082689173
# Колмогорова - Смирнова:
# Встроенный: 0.5486851446031328 Перестановочный: 0.5458545414545855

# %% [markdown]
# ## $\mathcal{N}(1,1)$
#
# (С двусторонней альтернативой)

# %%
comparison(stat.norm(1,1), samplesize = 25)

# %%
double_pvalue(stat.norm(1,1), perms = 10000, samplesize = 20)
# Out:
# Манна - Уитни:
# Встроенный: 0.010176944502960148 Перестановочный: 0.009399060093990608
# Колмогорова - Смирнова:
# Встроенный: 0.012298612583953778 Перестановочный: 0.012698730126987301

# %% [markdown]
# ## $\mathcal{N}(0,3/2)$

# %%
comparison(stat.norm(0, m.sqrt(3/2)), samplesize = 600)

# %%
double_pvalue(stat.norm(0, m.sqrt(3/2)), perms = 10000)
# Out:
# Манна - Уитни:
# Встроенный: 0.31750224377774905 Перестановочный: 0.3211678832116789
# Колмогорова - Смирнова:
# Встроенный: 0.7166468440414822 Перестановочный: 0.7155284471552845

# %% [markdown]
# # $t_k$
# $k = 3 \quad k = 42$

# %%
comparison(stat.t(3), samplesize = 360)

# %%
comparison(stat.t(42), samplesize = 360)

# %%
double_pvalue(stat.t(3), perms = 10000)
# Out:
# Манна - Уитни:
# Встроенный: 0.19259799276641898 Перестановочный: 0.19118088191180882
# Колмогорова - Смирнова:
# Встроенный: 0.5486851446031328 Перестановочный: 0.5483451654834517

# %%
double_pvalue(stat.t(42), perms = 10000)
# Out:
# Манна - Уитни:
# Встроенный: 0.1788530519564675 Перестановочный: 0.17738226177382266
# Колмогорова - Смирнова:
# Встроенный: 0.2719135601522248 Перестановочный: 0.2726727327267273

# %% [markdown]
# ### Центрированная нормированная сумма экспоненциальных

# %% [markdown]
# ##### k = 3

# %%
iters = 100; samplesize = 100; k = 3

pmw = []; pks = [];
for i in range(iters):
    xsample = X(0,1).rvs(samplesize)
    ysample = []
    for j in range(samplesize):
        ysample.append(np.sum(stat.expon().rvs(k) - 1)/m.sqrt(k))
        
   # print(ysample)
    
    pmw.append(stat.mannwhitneyu(xsample, ysample, use_continuity=False, alternative='two-sided')[1])
    pks.append(stat.ks_2samp(xsample, ysample, alternative='two-sided', mode='auto')[1])
    
xaxes = np.linspace(0, 1, iters)
plt.plot(np.sort(pmw), xaxes, label = 'Манна - Уитни')
plt.plot(sorted(pks), xaxes, label = 'Колмогорова - Смирнова')
plt.plot(xaxes, xaxes)
plt.legend()
plt.show()

# %% [markdown]
# ###### k = 42

# %%
iters = 100; samplesize = 100; k = 42

pmw = []; pks = [];
for i in range(iters):
    xsample = X(0,1).rvs(samplesize)
    ysample = []
    for j in range(samplesize):
        ysample.append(np.sum(stat.expon().rvs(k) - 1)/m.sqrt(k))
        
   # print(ysample)
    
    pmw.append(stat.mannwhitneyu(xsample, ysample, use_continuity=False, alternative='two-sided')[1])
    pks.append(stat.ks_2samp(xsample, ysample, alternative='two-sided', mode='auto')[1])
    
xaxes = np.linspace(0, 1, iters)
plt.plot(np.sort(pmw), xaxes, label = 'Манна - Уитни')
plt.plot(sorted(pks), xaxes, label = 'Колмогорова - Смирнова')
plt.plot(xaxes, xaxes)
plt.legend()
plt.show()

# %% [markdown]
# ###### k = 5

# %%
perms = 10000; 

xsample = X(0,1).rvs(samplesize)
ysample = []; k = 5
for j in range(samplesize):
    ysample.append(np.sum(stat.expon().rvs(k) - 1)/k)
    
pmw = stat.mannwhitneyu(xsample, ysample, use_continuity=False, alternative='two-sided')[1]
pks = stat.ks_2samp(xsample, ysample, alternative='two-sided', mode='exact')[1]

countermw = 0; counterks = 0;
for i in range(perms):
    tmp = np.concatenate((xsample, ysample), axis = None)
        
    tmp = np.random.permutation(tmp)
        #ysample = np.random.permutation(ysample)
    xsample = tmp[:samplesize]
    ysample = tmp[samplesize:2 * samplesize]
        
    if (stat.mannwhitneyu(xsample, ysample, use_continuity=False, alternative='two-sided')[1] > pmw):
        countermw += 1
        
    if (stat.ks_2samp(xsample, ysample, alternative='two-sided', mode='exact')[1] > pks):
        counterks += 1
            
print('Манна - Уитни:')
print('Встроенный:', pmw, 'Перестановочный:', 1 - (countermw + 1) / (perms + 1))
    
print('Колмогорова - Смирнова:')
print('Встроенный:', pks, 'Перестановочный:', 1 - (counterks + 1) / (perms + 1))
# Out:
# Манна - Уитни:
# Встроенный: 0.13674460867512028 Перестановочный: 0.1355864413558644
# Колмогорова - Смирнова:
# Встроенный: 0.0007377026282063397 Перестановочный: 0.0007999200079992219

# %% [markdown]
# Критерий Колмогорова - Смирнова различает величины с одинаковым средним  намного лучше, чем критерий Манна - Уитни.
# Критерий М - В лучше различил величины с разным средним
